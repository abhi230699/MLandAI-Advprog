# %% [markdown]
# CSE-221710302039-M.ABHISHEK NAIDU

# %% [markdown]
# Read an image(which contains different objects) using matplotlib and check the shape of the image?
#
# Display the image?
#
# Identify the different objects in the image?
#
# Use slicing to get the objects and display them?

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ig=plt.imread("data:image/png;base64,...")
print(ig.shape)
# Out:
# (249, 378, 4)

# %%
plt.imshow(ig)

# %%
plt.imshow(ig[:,:,0])

# %%
plt.imshow(ig[:,:,0],cmap='gray')

# %%
plt.imshow(ig[:,0:100])

# %%
plt.imshow(ig[:400,:400])

# %%
plt.imshow(ig[100:300,135:175]) #indian jersey

# %%
plt.imshow(ig[200:,:500]) #shoes of players
